# %%
import pandas as pd

# %%
week_pricing = pd.read_csv("agriBORA_maize_prices_week_46.csv")
week_pricing.head()
# Out:
#       Week       County  AvgPricePerBag  BagSizeKg  AvgPricePerKg
# 0  2025-46       Kiambu            3450         90      38.333333
# 1  2025-46    Kirinyaga            3500         90      38.888889
# 2  2025-46      Mombasa            3250         90      36.111111
# 3  2025-46      Nairobi            3312         90      36.800000
# 4  2025-46  Uasin-Gishu            2990         90      33.222222

# %%
historical_pricing_data = pd.read_csv("kamis_maize_prices.csv")
historical_pricing_data.head()
# Out:
#       Commodity_Classification  Commodity     Classification   County  \
# 0              Dry_White_Maize  Dry_Maize        White_Maize  Baringo
# 1              Dry_White_Maize  Dry_Maize        White_Maize  Baringo
# 2              Dry_White_Maize  Dry_Maize        White_Maize  Baringo
# 3  Dry_Maize_Mixed_Traditional  Dry_Maize  Mixed_Traditional  Baringo
# 4              Dry_White_Maize  Dry_Maize        White_Maize  Baringo
#
#                  Market        Date  Year  Month Year_Month  WeekofYear  \
# 0       Kabarnet_Market  2021-05-24  2021      5    2021-05          21
# 1        Marigat_Market  2021-05-24  2021      5    2021-05          21
# 2        Marigat_Market  2021-05-24  2021      5    2021-05          21
# 3  Eldama_Ravine_Market  2021-05-24  2021      5    2021-05          21
# 4        Marigat_Market  2021-05-24  2021      5    2021-05          21
#
#   Year_Week  SupplyVolume  Retail  Wholesale Unit
# 0   2021-21        2700.0    30.0      25.00   Kg
# ...

# %%
print(historical_pricing_data['County'].value_counts())
# Out:
# County
# Nairobi            2125
# Nakuru             1755
# Siaya              1709
# Kirinyaga          1216
# Migori             1072
# Kisumu              866
# Uasin-Gishu         826
# Nandi               686
# Kisii               668
# Vihiga              613
# Tharaka-Nithi       602
# Trans-Nzoia         589
# Meru                587
# Embu                580
# Nyeri               518
# West-Pokot          496
# Baringo             470
# Kajiado             427
# Nyamira             404
# Mandera             402
# Kwale               394
# Bomet               387
# Kitui               380
# Homa-Bay            371
# Nyandarua           351
# Machakos            329
# Taita-Taveta        316
# Bungoma             275
# Makueni             256
# Busia               243
# Kakamega            237
# Kericho             228
# Elgeyo-Marakwet     221
# Garissa             216
# Lamu                183
# Laikipia            166
# Muranga             161
# Turkana             128
# ...

# %%
rows_to_drop =
# Out:
#   Cell In[20], line 1
#     pandas.read_sql_query(DELETE FROM historical_pricing_data
#                           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
raw_historical_prices = pd.read_csv("kamis_maize_prices_raw.csv")
raw_historical_prices.head()
# Out:
#    Commodity Classification Grade Sex          Market Wholesale Retail  \
# 0  dry maize    white maize     -   -      kawangware      55.0   65.0
# 1  dry maize    white maize     -   -        kipkaren      65.0   80.0
# 2  dry maize    white maize     -   -  kangemi market       NaN   55.0
# 3  dry maize   yellow maize     -   -         gikomba     77.78  100.0
# 4  dry maize    white maize     -   -         gikomba     52.22   65.0
#
#    Supply Volume    County        Date Unit Source  Year Month Year-Month  \
# 0            NaN   Nairobi  2025-07-31  NaN    NaN  2025  July    2025-07
# 1        10000.0  Kakamega  2025-07-31  NaN    NaN  2025  July    2025-07
# 2            NaN   Nairobi  2025-07-31  NaN    NaN  2025  July    2025-07
# 3            NaN   Nairobi  2025-07-31  NaN    NaN  2025  July    2025-07
# 4            NaN   Nairobi  2025-07-31  NaN    NaN  2025  July    2025-07
#
#    Week
# 0    31
# 1    31
# 2    31
# 3    31
# 4    31

# %%
raw_historical_prices.drop('Grade', axis=1, inplace=True)

# %%
raw_historical_prices.drop('Sex', axis=1, inplace=True)

# %%
raw_historical_prices.head()
# Out:
#    Commodity Classification          Market Wholesale Retail  Supply Volume  \
# 0  dry maize    white maize      kawangware      55.0   65.0            NaN
# 1  dry maize    white maize        kipkaren      65.0   80.0        10000.0
# 2  dry maize    white maize  kangemi market       NaN   55.0            NaN
# 3  dry maize   yellow maize         gikomba     77.78  100.0            NaN
# 4  dry maize    white maize         gikomba     52.22   65.0            NaN
#
#      County        Date Unit Source  Year Month Year-Month  Week
# 0   Nairobi  2025-07-31  NaN    NaN  2025  July    2025-07    31
# 1  Kakamega  2025-07-31  NaN    NaN  2025  July    2025-07    31
# 2   Nairobi  2025-07-31  NaN    NaN  2025  July    2025-07    31
# 3   Nairobi  2025-07-31  NaN    NaN  2025  July    2025-07    31
# 4   Nairobi  2025-07-31  NaN    NaN  2025  July    2025-07    31

# %%
print(raw_historical_prices['County'].value_counts())
# Out:
# County
# Nairobi            2296
# Nakuru             1969
# Siaya              1724
# Kirinyaga          1216
# Migori             1073
# Kisumu              915
# Uasin-Gishu         827
# Nandi               689
# Kisii               669
# Vihiga              616
# Trans-Nzoia         605
# Tharaka-Nithi       602
# Meru                587
# Embu                581
# Nyeri               519
# West-Pokot          506
# Kajiado             486
# Baringo             470
# Mandera             415
# Nyamira             411
# Kwale               394
# Bomet               387
# Kitui               381
# Homa-bay            371
# Nyandarua           351
# Machakos            329
# Taita-Taveta        323
# Bungoma             295
# Makueni             261
# Busia               246
# Kakamega            243
# Elgeyo-Marakwet     233
# Kericho             228
# Garissa             216
# Lamu                183
# Laikipia            173
# Muranga             161
# Turkana             132
# ...
